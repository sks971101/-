# %% [markdown]
# # Matplotlib(맷플롯립)
# - 파이썬에서 자료를 차트(chart)나 플롯(plot)로 시각화하는 패키지
# - http://matplotlib.org/gallery.html
# - 라인 플롯(line plot)
# - 산점도(산포도, scatter plot)
# - 컨투어 플롯(contour plot)
# - 서피스 플롯(surface plot)
# - 바 플롯(bar plot)
# - 히스토그램(histogram)
# - 박스 플롯(box plot)

# %% [markdown]
# ## 필수 라이브러리 로딩

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# ## 라인 플롯(Line Plot)
# - 시계열 데이터를 처리할 때 유용한 시각화도구
# - plot(y축)
# - plot(x축, y축)
# - 데이터는 리스트타입의 데이터를 담아야 한다.
# - ndarray 객체

# %%
# 차트 제목
plt.title('Line Plot')
# 라인플롯
plt.plot([1, 4, 9, 16])
# 시각화
plt.show()

# %%
plt.title('x ticks')
plt.plot([10, 20, 30, 40],[1, 4, 9, 16])
plt.show()

# %% [markdown]
# **한글 폰트 설정**
# - matplotlib는 한글지원을 하지 않는다.
# - 그래프에 한글을 담아서 출력하기 위해 한글폰트의 설정이 필요하다.

# %%
# 폰트 설정
mpl.rc('font', family='Malgun Gothic')
# 한글 문자열은 항상 유니코드 설정 : 음수 부호 설정
mpl.rc('axes', unicode_minus=False)

# %%
plt.title('한글 제목') # plt.title('한글제목', fontdict=font1)
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.xlabel('x축 제목')
plt.ylabel('y축 제목')
plt.show()

# %%
# 한글처리
plt.rc('font', family='Malgun Gothic')

# %% [markdown]
# - http://hangeul.naver.com/2017/nanum

# %% [markdown]
# ### 스타일 지정(style)

# %%
plt.title(" 'rs--' 스타일이 적용된 plot ")
# color, marker, line style 순서대로 지정
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], 'rs--')
plt.show()

# %% [markdown]
# 1. 색깔 : https://matplotlib.org/2.0.2/examples/color/named_colors.html
#  - blue(b), green(g), red(r), cyan(c), magenta(m), yellow(y), black(k), white(w)
# 2. 마커(볼릿기호) : https://matplotlib.org/2.0.2/api/markers_api.html?highlight=marker#module-matplotlib.markers
# 3. 선 스타일 : 실선(solid), 대시선(dashed), 점선(dotted), 대시-점선(dash-dot)
# 4. 기타 스타일
# - color(c) : 선색깔
# - linewidth(lw) : 선굵기
# - linestyle(ls) : 선스타일
# - marker : 마커종류

# %%
plt.title(" 스타일 적용 그래프 ")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c='b',
         lw=5, ls='--', marker='o', ms=15, mec='g', mew=5, mfc='r')
plt.show()

# %% [markdown]
# ### 그림범위지정
# - xlim(min, max)
# - ylim(min, max)

# %%
plt.title(" 스타일 적용 그래프 ")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c='b',
         lw=5, ls='--', marker='o', ms=15, mec='g', mew=5, mfc='r')
plt.xlim(0, 50)
plt.ylim(-10, 30)
plt.show()

# %% [markdown]
# ### 틱(tick) 설정
# - 축에 위치를 표시하는 점을 틱(tick)이라고 한다.
# - 틱에 써있는 숫자 또는 글자를 틱 라벨(tick label)
# - xticks([])
# - yticks([])

# %%
x = np.linspace(-np.pi, np.pi, 256)
c = np.cos(x)
plt.title("x축과 y축 tick 설정")
plt.plot(x, c)
plt.show()

# %%
x = np.linspace(-np.pi, np.pi, 256)
c = np.cos(x)
plt.title("x축과 y축 tick 설정")
plt.plot(x, c)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1, 0, 1])
plt.show()

# %%
x = np.linspace(-np.pi, np.pi, 256)
c = np.cos(x)
plt.title("LaTeX 문자열을 이용한 수식을 ticks로 설정")
plt.plot(x, c)

plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

plt.yticks([-1, 0, 1], ["Low", "Zero", "High"])

plt.show()

# %% [markdown]
# ### 그리드 설정(grid line)
# - grid(False) or grid(True)

# %%
x = np.linspace(-np.pi, np.pi, 256)
c = np.cos(x)
plt.title("LaTeX 문자열을 이용한 수식을 ticks로 설정")
plt.plot(x, c)

plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

plt.yticks([-1, 0, 1], ["Low", "Zero", "High"])

plt.grid(True)

plt.show()

# %%
t = np.arange(0., 5., 0.2)
plt.title('여러개의 라이 플롯')
plt.plot(t, t, 'r--', t, 0.5*t**2, 'bs:', t, 0.2*t**3, 'g^-')
plt.show()

# %% [markdown]
# ### 범례(legend)
# - 하나의 차트에 여러개의 그래프를 그릴경우 각 그래프가 뜻하는 것을 표시하는 것
# - legend()
# - loc : best(0)
# - loc : upper right(1)
# - loc : upper left(2)
# - loc : lower left(3)
# - loc : lower right(4)
# - loc : right(5)
# - loc : center left(6)
# - loc : center right(7)
# - loc : lower center(8)
# - loc : upper center(9)
# - loic : center(10)

# %%
x = np.linspace(-np.pi, np.pi, 256)
c = np.cos(x)
s = np.sin(x)
plt.title('범례를 가진 그래프')
plt.plot(x, c, ls='--', label='cosine')
plt.plot(x, s, ls=':', label='sine')
plt.legend(loc=2)
plt.show()

# %% [markdown]
# ### x, y 축 제목, 차트제목
# - title
# - xlabel
# - ylabel

# %%
x = np.linspace(-np.pi, np.pi, 256)
c = np.cos(x)
s = np.sin(x)

plt.title('범례를 가진 그래프')
plt.plot(x, c, ls='--', label='cosine')
plt.plot(x, s, ls=':', label='sine')
plt.legend(loc=2)

plt.xlabel('time')
plt.ylabel('etc')
plt.show()

# %% [markdown]
# ## 그림 구조
# - Figure 객체 : 그림, 캔버스, 도화지, 종이
# - http://matplotlib.org/api/figure_api.html#matplotlib.figure.Figure
# - Axes 객체 : Figure 객체는 하나 이상의 Axes 객체
# - Axis 객체 : 축

# %%
fig = plt.figure(figsize=(10, 2))
plt.title('fig 객체를 이용한 도화지 크기 조정')
plt.plot(np.random.randn(100))

plt.show()

# %% [markdown]
# **Axes객체와 subplot()**
# - http://matplotlib.org/api/axes_api.html#matplotlib.axes.Axes
# - subplot(2, 1, 1)

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2*np.pi*x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'yo-')
plt.title('첫번째 subplot')
plt.ylabel('A')

ax2 = plt.subplot(2, 1, 2)
plt.plot(x2, y2, 'r.-')
plt.xlabel('time')
plt.ylabel('B')

# 플롯간의 간격을 자동으로 맞춰주는 메서드
plt.tight_layout()
plt.show()

# %%
plt.subplot(221)
plt.plot(np.random.rand(5))
plt.title('axes 1')

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title('axes 2')

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title('axes 3')

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title('axes 4')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Axis 객체와 축**
# - 하나의 Axes에 두 개 이상의 Axis 객체를 가진다.
# - https://matplotlib.org/api/axis_api.html
# - twinx() 메서드를 이용하여 복수개의 축을 설정한다.

# %%
fig, ax0 = plt.subplots()
ax1 = ax0.twinx()

ax0.set_title('2개의 y축을 가진 하나의 figure 객체')
ax0.plot([10, 5, 2, 9, 7], 'r-', label='y0')
ax0.set_ylabel('y0')
ax0.grid(True)

ax1.plot([100, 200, 220, 180, 120], 'g:', label='y1')
ax1.set_ylabel('y1')
ax1.grid(True)

ax0.set_xlabel('공유하는 x축')
plt.show()

# %%
fig, ax = plt.subplots(3, 4, figsize=(15, 10))

for row in range(3):
    for col in range(4):
        ax[row, col].plot(np.random.randn(10))
        ax[row, col].set_title(f"{row+1}행 {col+1}열")
        ax[row, col].set_xlabel(f"{row+1}행")
        ax[row, col].set_ylabel(f"{col+1}열", rotation = 0)
        
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Bar chart(바 차트)
# - bar() : 수직막대
# - barh() : 수평막대
# - http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.bar
# - http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.barh

# %%
np.random.seed(100)
a = np.random.randn(10)
print(a)
b = a.cumsum() # 누적합
print(b)

s = pd.Series(b, index = np.arange(0, 100, 10))
print(s)
# Out:
# [-1.74976547  0.3426804   1.1530358  -0.25243604  0.98132079  0.51421884
#   0.22117967 -1.07004333 -0.18949583  0.25500144]
# [-1.74976547 -1.40708507 -0.25404927 -0.5064853   0.47483548  0.98905432
#   1.21023399  0.14019066 -0.04930517  0.20569628]
# 0    -1.749765
# 10   -1.407085
# 20   -0.254049
# 30   -0.506485
# 40    0.474835
# 50    0.989054
# 60    1.210234
# 70    0.140191
# 80   -0.049305
# 90    0.205696
# dtype: float64

# %%
# x축 index, y축 data
s.plot()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.randn(10, 4), columns=['A', 'B', 'C', 'D'],
                 index = np.arange(0, 100, 10))
df
# Out:
#            A         B         C         D
# 0  -0.458027  0.435163 -0.583595  0.816847
# 10  0.672721 -0.104411 -0.531280  1.029733
# 20 -0.438136 -1.118318  1.618982  1.541605
# 30 -0.251879 -0.842436  0.184519  0.937082
# 40  0.731000  1.361556 -0.326238  0.055676
# 50  0.222400 -1.443217 -0.756352  0.816454
# 60  0.750445 -0.455947  1.189622 -1.690617
# 70 -1.356399 -1.232435 -0.544439 -0.668172
# 80  0.007315 -0.612939  1.299748 -1.733096
# 90 -0.983310  0.357508 -1.613579  1.470714

# %%
# y축 필드값, x축 인덱스
df.plot()
# Out:
# <Axes: >

# %%
df['A'].plot()
# Out:
# <Axes: >

# %%
s2 = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))
s2
# Out:
# a    0.363188
# b    0.204345
# c    0.276765
# d    0.246536
# e    0.173608
# f    0.966610
# g    0.957013
# h    0.597974
# i    0.731301
# j    0.340385
# k    0.092056
# l    0.463498
# m    0.508699
# n    0.088460
# o    0.528035
# p    0.992158
# dtype: float64

# %%
s2.plot(kind='bar')
# Out:
# <Axes: >

# %%
s2.plot(kind='barh')
# Out:
# <Axes: >

# %%
y = [2, 3, 1]
x = np.arange(len(y)) # 0, 1, 2
xlabel = ['가','나','다']

plt.title('bar chart')
plt.bar(x, y)
plt.xticks(x, xlabel)
plt.yticks(sorted(y))
plt.xlabel('가나다')
plt.ylabel('빈도수')

plt.show()

# %%
y = [2, 3, 1]
x = np.arange(len(y)) # 0, 1, 2
xlabel = ['가','나','다']

plt.title('bar chart')
plt.barh(x, y, alpha=0.4)
plt.xticks(x, xlabel)
plt.yticks(sorted(y))
plt.xlabel('가나다')
plt.ylabel('빈도수')

plt.show()

# %% [markdown]
# **stem plot(스템플롯)**
# - 바 차트와 유사하지만 폭(width)이 없는 그래프
# - 주로 이산확률함수나 자기상관관계를 나타낼 때 사용
# - http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.stem

# %%
x = np.linspace(0.1, 2*np.pi, 10)
markerline, stemlines, baseline = plt.stem(x, np.cos(x), '-.')
plt.setp(baseline, 'color', 'r', 'linewidth', 2)
plt.show()

# %%
x = np.linspace(0.1, 2 * np.pi, 10)
plt.title("Stem Plot")
plt.stem(x, np.cos(x), '-.')
plt.show()

# %% [markdown]
# ## 파이 차트(Pie Chart)
# - 카테고리별값이 상대적인 비교를 할 때사용
# - pie()
# - 파이 차트를 그릴 때 원의 형태를 유지하도록 plt.axis('equal') 명령
# - http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.pie

# %%
labels = ['개구리', '돼지', '개', '통나무']
sizes = [15, 30, 45, 10]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0.1, 0, 0)

# title
plt.title("Pie Chart")

# pie chart
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)

# pie chart 사용시 실행
plt.axis('equal')

plt.show()

# %% [markdown]
# ## 히스토그램(Histogram)
# - hist()
# - bins : 구간 정보
# - http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.hist

# %%
np.random.seed(0)
x = np.random.randn(1000)

plt.title('히스토그램')

arrays, bins, patches = plt.hist(x, bins=10)

plt.show()

# %%
arrays
# Out:
# array([  9.,  20.,  70., 146., 217., 239., 160.,  86.,  38.,  15.])

# %%
bins
# Out:
# array([-3.04614305, -2.46559324, -1.88504342, -1.3044936 , -0.72394379,
#        -0.14339397,  0.43715585,  1.01770566,  1.59825548,  2.1788053 ,
#         2.75935511])

# %% [markdown]
# ## 스캐터 플롯(scatter plot)
# - 산점도(산포도) : 데이터의 분포를 파악하는 시각화도구
# - http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.scatter

# %%
np.random.seed(0)
x = np.random.normal(0, 1, 100)
y = np.random.normal(0, 1, 100)

plt.title('Scatter Plot')

plt.scatter(x, y)

plt.show()

# %%
# 2차원이 아니라 3차원 또는 4차원인 경우에는 점 하나의 크기 혹은 색깔을 이용해서 시각화한다.
# 버블 차트(bubble chart)라고 부른다.
# s:크기, c:색상
N = 30
np.random.seed(0)
x = np.random.rand(N)
y1 = np.random.rand(N)
y2 = np.random.rand(N)
y3 = np.pi * (15 * np.random.rand(N)) ** 2

plt.title('Bubble Chart')

plt.scatter(x, y1, c=y2, s=y3)

plt.show()

# %% [markdown]
# ## Imshow
# - 화상(image) 데이터를 행과 열이 있는 2차원 데이터로 imshow()
# - http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.imshow

# %%
from sklearn.datasets import load_digits

digits = load_digits()

x = digits.images[0]
x
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
plt.imshow(x)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# # Seaborn(시본)
# - matplotlib을 기반으로 다양한 색상 테마, 통계용 차트등의 기능을 제공하는 시각화 패키지
# - Matplotlib 패키지에 의존, Statsmodels 패키지를 의존해서 통계 시각화
# - http://seaborn.pydata.org/

# %% [markdown]
# ## 샘플 데이터 로딩
# https://github.com/mwaskom/seaborn-data

# %%
import seaborn as sns
# 붖꽃 데이터
iris = sns.load_dataset('iris')
# 타이타닉 데이터
titanic = sns.load_dataset('titanic')
# 팁 데이터
tips = sns.load_dataset('tips')
# 여객운송 데이터
flights = sns.load_dataset('flights')

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data = iris.petal_length.values
y = iris.petal_length.index

plt.scatter(data, y)
sns.rugplot(data)

plt.show()

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.set_theme()
sns.kdeplot(data=iris, y="petal_length")
plt.show()
